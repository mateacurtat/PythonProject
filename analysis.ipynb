# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "/content/ComportementCMS.xlsx"

df_raw = pd.read_excel(file_path)
print("Shape:", df_raw.shape)
df_raw.head()
# Out:
# Shape: (94, 20)
#      Group  Rat  Diff cort  Time open arm  Distance EPM  Entries open arm  \
# 0  Control    1   0.478106          0.000      1837.203                 0
# 1  Control    7   1.433348         18.199      1864.775                 8
# 2  Control    8  -0.555555         89.237      2344.051                26
# 3  Control    9  -0.260418         42.322      2074.205                10
# 4  Control   10   0.148606         28.720      1953.833                16
#
#    Ambulatory episodes (0-15)  Ambulatory episodes (0-60)  \
# 0                          58                         120
# 1                          59                         105
# 2                          37                          50
# 3                          22                          60
# 4                          29                          68
#
#    Ambulatory distance (0-15)  Ambulatory distance (0-60)  \
# 0                 1806.147923                 3944.027865
# 1                 2225.480201                 4532.696406
# 2                 1476.823035                 2238.255822
# 3                  837.296882                 2319.498909
# 4                  984.790146                 2326.607538
#
#    Resting time (s) (0-60)  Vertical count (0-15)  Vertical count (0-60)  \
# 0                  3057.65                     83                    279
# 1                  2983.25                     83                    170
# 2                  3131.15                    109                    182
# 3                  3191.00                     45                    145
# 4                  3142.10                     52                    143
#
#    Vertical time (0-15)  Vertical time (0-60)  Time in central zone (0-15)  \
# 0                 96.50                472.25                         9.80
# 1                196.00                451.80                        53.30
# 2                169.15                315.25                        37.20
# 3                137.90                513.00                         1.45
# 4                135.05                344.30                        11.60
#
#    Time in central zone (0-60)  Mean PPI 10 stim  Mean PPI (-72) 10 stim  \
# 0                        37.45         38.934565               47.328903
# 1                       203.60         34.270582               47.612742
# 2                        98.40         62.247016               65.535375
# 3                        11.40         28.975819               38.983797
# 4                        56.70         47.275544               56.580008
#
#    ST 10 stim
# 0      443.95
# 1      641.95
# 2      481.75
# 3      605.85
# 4      661.60

# %%
df = df_raw.copy()

# Nettoyer les noms de colonnes
df.columns = (
    df.columns
    .astype(str)
    .str.strip()
    .str.replace("\n", " ", regex=False)
    .str.replace("\r", " ", regex=False)
    .str.replace(r"\s+", " ", regex=True)
)

df.columns
# Out:
# Index(['Group', 'Rat', 'Diff cort', 'Time open arm', 'Distance EPM',
#        'Entries open arm', 'Ambulatory episodes (0-15)',
#        'Ambulatory episodes (0-60)', 'Ambulatory distance (0-15)',
#        'Ambulatory distance (0-60)', 'Resting time (s) (0-60)',
#        'Vertical count (0-15)', 'Vertical count (0-60)',
#        'Vertical time (0-15)', 'Vertical time (0-60)',
#        'Time in central zone (0-15)', 'Time in central zone (0-60)',
#        'Mean PPI 10 stim', 'Mean PPI (-72) 10 stim', 'ST 10 stim'],
#       dtype='object')
